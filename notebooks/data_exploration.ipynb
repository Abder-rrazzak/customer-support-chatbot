# %% [markdown]
# # Customer Support Data Exploration
#
# This notebook explores the customer support conversation data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
# df = pd.read_csv('../data/raw/conversations.csv')
print('Data exploration notebook ready')
